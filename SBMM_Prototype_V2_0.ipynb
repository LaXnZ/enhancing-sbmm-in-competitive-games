# %% [markdown]
# <a href="https://colab.research.google.com/github/LaXnZ/Player-Skill-Modeling-Starcraft-II/blob/prototype/SBMM_Prototype_V2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##SCENARIO 1: Premade Team 1

# %%
import pandas as pd
import numpy as np
import joblib
import random
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="sklearn")

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Load the saved model
model_path = '/content/drive/MyDrive/Final Year Project - APIIT/Models/logistic_regression_model.pkl'
model = joblib.load(model_path)

# Load the testing dataset
test_data_path = '/content/drive/MyDrive/Final Year Project - APIIT/Datasets/testing_data.csv'
test_data = pd.read_csv(test_data_path)

# Add player identifiers
test_data['Player'] = ['Player' + str(i) for i in range(1, len(test_data) + 1)]

# Separate features
X_test = test_data.drop(columns=['Target', 'Player'])
y_test = test_data['Target']

# Predict skill rating
test_data['SkillRating'] = model.predict_proba(X_test)[:, 1]
df_sorted = test_data.sort_values(by='SkillRating', ascending=False).reset_index(drop=True)

# Scenario 1 Header
print("\033[1m" + "="*50)
print(" SCENARIO 1: Premade Team 1 (Top 5 Skilled Players)")
print("="*50 + "\033[0m\n")

# Fix Team 1 as top 5 skilled players
fixed_team1 = df_sorted.iloc[:5][['Player', 'SkillRating']].values.tolist()
team1_df = pd.DataFrame(fixed_team1, columns=['Player', 'SkillRating'])

print("\033[1;36mFixed Team 1:\033[0m")
print(team1_df.to_string(index=False))
print()

# Remaining players for Team 2 matching
remaining_pool = df_sorted.iloc[5:][['Player', 'SkillRating']].values.tolist()
found_match = False
attempts = 0

while not found_match and len(remaining_pool) >= 5:
    random.shuffle(remaining_pool)
    team2 = remaining_pool[:5]

    total1 = sum(p[1] for p in fixed_team1)
    total2 = sum(p[1] for p in team2)
    fairness = abs(total1 - total2)
    precision = 1 / (1 + fairness)

    attempts += 1

    print(f"\n\033[1m× Attempt {attempts} ×\033[0m")
    print("\033[94mTeam 2:\033[0m")
    print(pd.DataFrame(team2, columns=['Player', 'SkillRating']).to_string(index=False))

    print(f"\n\033[93mTeam 1 Total Skill:\033[0m {total1:.2f}")
    print(f"\033[93mTeam 2 Total Skill:\033[0m {total2:.2f}")
    print(f"\033[95mFairness (Skill Difference):\033[0m {fairness:.2f}")
    print(f"\033[92mPrecision (Balance of the teams):\033[0m {precision:.2f}")

    if precision > 0.8:
        print("\n\033[1;32m✅ Highly Balanced Match Found!\033[0m")
        print("\n\033[1;34mFinal Matched Team 2:\033[0m")
        print(pd.DataFrame(team2, columns=['Player', 'SkillRating']).to_string(index=False))

        print(f"\n\033[92mFairness Score:\033[0m {fairness:.2f}")
        print(f"\033[92mPrecision Score:\033[0m {precision:.2f} \033[90m(Closer to 1 is better)\033[0m")
        found_match = True
        break

if not found_match:
    print("\n\033[1;31m❌ Could not find a highly balanced team after 100 attempts.\033[0m")

print(f"\n\033[1mTotal Attempts Made:\033[0m {attempts}")
print("\n\033[90m--- End of Simulation ---\033[0m")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ==================================================
#  SCENARIO 1: Premade Team 1 (Top 5 Skilled Players)
# ==================================================
#
# Fixed Team 1:
#    Player  SkillRating
# Player142     0.999903
#  Player46     0.999679
#  Player18     0.999499
# Player139     0.998925
# Player109     0.998665
#
#
# × Attempt 1 ×
# Team 2:
#    Player  SkillRating
#  Player71     0.046209
#  Player92     0.910846
# Player122     0.542332
#   Player6     0.980940
#  Player43     0.154134
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.63
# Fairness (Skill Difference): 2.36
# Precision (Balance of the teams): 0.30
#
# × Attempt 2 ×
# Team 2:
#    Player  SkillRating
#  Player73     0.918321
# Player126     0.109776
# Player110     0.728264
# Player117     0.974707
#  Player97     0.052538
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.78
# Fairness (Skill Difference): 2.21
# Precision (Balance of the teams): 0.31
#
# × Attempt 3 ×
# Team 2:
#    Player  SkillRating
# Player149     0.969792
#  Player38     0.781405
#  Player91     0.989575
# Player137     0.086768
#  Player86     0.136276
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.96
# Fairness (Skill Difference): 2.03
# Precision (Balance of the teams): 0.33
#
# × Attempt 4 ×
# Team 2:
#    Player  SkillRating
#  Player42     0.146179
#  Player13     0.989955
# Player130     0.928663
#  Player66     0.868816
#  Player80     0.049415
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.98
# Fairness (Skill Difference): 2.01
# Precision (Balance of the teams): 0.33
#
# × Attempt 5 ×
# Team 2:
#    Player  SkillRating
#   Player6     0.980940
#   Player8     0.003246
#  Player69     0.014513
# Player117     0.974707
#  Player71     0.046209
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.02
# Fairness (Skill Difference): 2.98
# Precision (Balance of the teams): 0.25
#
# × Attempt 6 ×
# Team 2:
#    Player  SkillRating
#  Player12     0.079175
# Player134     0.051987
#  Player49     0.026234
#  Player97     0.052538
#  Player98     0.014025
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 0.22
# Fairness (Skill Difference): 4.77
# Precision (Balance of the teams): 0.17
#
# × Attempt 7 ×
# Team 2:
#    Player  SkillRating
#  Player14     0.011411
#  Player77     0.043495
# Player122     0.542332
# Player138     0.686361
#  Player91     0.989575
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.27
# Fairness (Skill Difference): 2.72
# Precision (Balance of the teams): 0.27
#
# × Attempt 8 ×
# Team 2:
#   Player  SkillRating
# Player19     0.259313
#  Player6     0.980940
# Player79     0.986732
# Player40     0.117620
# Player14     0.011411
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.36
# Fairness (Skill Difference): 2.64
# Precision (Balance of the teams): 0.27
#
# × Attempt 9 ×
# Team 2:
#    Player  SkillRating
# Player134     0.051987
#  Player42     0.146179
#  Player24     0.000062
# Player145     0.986853
#  Player32     0.626015
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 1.81
# Fairness (Skill Difference): 3.19
# Precision (Balance of the teams): 0.24
#
# × Attempt 10 ×
# Team 2:
#    Player  SkillRating
#  Player75     0.518849
# Player111     0.561146
#  Player93     0.738337
#   Player4     0.312418
#  Player50     0.328119
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.46
# Fairness (Skill Difference): 2.54
# Precision (Balance of the teams): 0.28
#
# × Attempt 11 ×
# Team 2:
#    Player  SkillRating
# Player138     0.686361
#  Player45     0.481439
#   Player1     0.997201
#  Player20     0.423546
# Player141     0.803060
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 3.39
# Fairness (Skill Difference): 1.61
# Precision (Balance of the teams): 0.38
#
# × Attempt 12 ×
# Team 2:
#    Player  SkillRating
#  Player11     0.608037
#  Player30     0.942929
#  Player99     0.957700
#  Player65     0.472560
# Player122     0.542332
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 3.52
# Fairness (Skill Difference): 1.47
# Precision (Balance of the teams): 0.40
#
# × Attempt 13 ×
# Team 2:
#    Player  SkillRating
#   Player9     0.052345
#  Player23     0.153125
# Player100     0.747504
#  Player32     0.626015
#  Player45     0.481439
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.06
# Fairness (Skill Difference): 2.94
# Precision (Balance of the teams): 0.25
#
# × Attempt 14 ×
# Team 2:
#    Player  SkillRating
#  Player20     0.423546
#  Player91     0.989575
# Player100     0.747504
# Player111     0.561146
#   Player6     0.980940
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 3.70
# Fairness (Skill Difference): 1.29
# Precision (Balance of the teams): 0.44
#
# × Attempt 15 ×
# Team 2:
#    Player  SkillRating
#  Player41     0.061890
#   Player9     0.052345
# Player101     0.852247
#  Player61     0.038503
#  Player19     0.259313
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 1.26
# Fairness (Skill Difference): 3.73
# Precision (Balance of the teams): 0.21
#
# × Attempt 16 ×
# Team 2:
#    Player  SkillRating
# Player145     0.986853
#  Player69     0.014513
#  Player89     0.179606
# Player115     0.425807
#  Player44     0.766610
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.37
# Fairness (Skill Difference): 2.62
# Precision (Balance of the teams): 0.28
#
# × Attempt 17 ×
# Team 2:
#    Player  SkillRating
# Player143     0.859454
#  Player13     0.989955
#  Player81     0.193907
# Player106     0.936561
#  Player74     0.960931
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 3.94
# Fairness (Skill Difference): 1.06
# Precision (Balance of the teams): 0.49
#
# × Attempt 18 ×
# Team 2:
#    Player  SkillRating
#  Player75     0.518849
#  Player99     0.957700
# Player105     0.047868
#  Player32     0.626015
#   Player3     0.417889
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.57
# Fairness (Skill Difference): 2.43
# Precision (Balance of the teams): 0.29
#
# × Attempt 19 ×
# Team 2:
#    Player  SkillRating
#  Player16     0.241174
#  Player72     0.833131
#  Player41     0.061890
# Player121     0.670517
#  Player23     0.153125
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 1.96
# Fairness (Skill Difference): 3.04
# Precision (Balance of the teams): 0.25
#
# × Attempt 20 ×
# Team 2:
#    Player  SkillRating
# Player108     0.887631
#   Player9     0.052345
#  Player38     0.781405
#  Player74     0.960931
#  Player40     0.117620
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.80
# Fairness (Skill Difference): 2.20
# Precision (Balance of the teams): 0.31
#
# × Attempt 21 ×
# Team 2:
#    Player  SkillRating
#  Player83     0.478687
#   Player5     0.618520
# Player119     0.990757
#  Player36     0.269491
#  Player73     0.918321
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 3.28
# Fairness (Skill Difference): 1.72
# Precision (Balance of the teams): 0.37
#
# × Attempt 22 ×
# Team 2:
#    Player  SkillRating
#  Player74     0.960931
# Player104     0.192236
# Player145     0.986853
#  Player26     0.055773
# Player119     0.990757
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 3.19
# Fairness (Skill Difference): 1.81
# Precision (Balance of the teams): 0.36
#
# × Attempt 23 ×
# Team 2:
#    Player  SkillRating
# Player145     0.986853
#  Player83     0.478687
#  Player56     0.268606
#  Player87     0.919898
#  Player38     0.781405
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 3.44
# Fairness (Skill Difference): 1.56
# Precision (Balance of the teams): 0.39
#
# × Attempt 24 ×
# Team 2:
#    Player  SkillRating
# Player110     0.728264
# Player145     0.986853
#  Player86     0.136276
#  Player26     0.055773
# Player113     0.070160
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 1.98
# Fairness (Skill Difference): 3.02
# Precision (Balance of the teams): 0.25
#
# × Attempt 25 ×
# Team 2:
#    Player  SkillRating
# Player100     0.747504
#  Player48     0.803324
#  Player98     0.014025
#  Player20     0.423546
#  Player52     0.141043
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.13
# Fairness (Skill Difference): 2.87
# Precision (Balance of the teams): 0.26
#
# × Attempt 26 ×
# Team 2:
#   Player  SkillRating
# Player98     0.014025
# Player96     0.064459
# Player39     0.992329
# Player80     0.049415
# Player84     0.997575
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.12
# Fairness (Skill Difference): 2.88
# Precision (Balance of the teams): 0.26
#
# × Attempt 27 ×
# Team 2:
#    Player  SkillRating
# Player125     0.942974
# Player140     0.513909
# Player116     0.773957
#  Player52     0.141043
#  Player82     0.974849
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 3.35
# Fairness (Skill Difference): 1.65
# Precision (Balance of the teams): 0.38
#
# × Attempt 28 ×
# Team 2:
#   Player  SkillRating
# Player50     0.328119
# Player76     0.990286
# Player22     0.533104
# Player15     0.001684
# Player30     0.942929
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.80
# Fairness (Skill Difference): 2.20
# Precision (Balance of the teams): 0.31
#
# × Attempt 29 ×
# Team 2:
#    Player  SkillRating
# Player104     0.192236
#  Player44     0.766610
#   Player9     0.052345
#  Player45     0.481439
# Player135     0.960674
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.45
# Fairness (Skill Difference): 2.54
# Precision (Balance of the teams): 0.28
#
# × Attempt 30 ×
# Team 2:
#    Player  SkillRating
#  Player12     0.079175
# Player103     0.988422
# Player132     0.065781
#  Player66     0.868816
# Player145     0.986853
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.99
# Fairness (Skill Difference): 2.01
# Precision (Balance of the teams): 0.33
#
# × Attempt 31 ×
# Team 2:
#    Player  SkillRating
#  Player82     0.974849
#  Player85     0.054628
#  Player38     0.781405
#  Player92     0.910846
# Player140     0.513909
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 3.24
# Fairness (Skill Difference): 1.76
# Precision (Balance of the teams): 0.36
#
# × Attempt 32 ×
# Team 2:
#    Player  SkillRating
#  Player49     0.026234
# Player106     0.936561
#  Player60     0.004512
#  Player54     0.935830
#  Player10     0.997955
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.90
# Fairness (Skill Difference): 2.10
# Precision (Balance of the teams): 0.32
#
# × Attempt 33 ×
# Team 2:
#    Player  SkillRating
# Player146     0.006691
# Player128     0.996869
# Player141     0.803060
#   Player4     0.312418
# Player147     0.009133
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.13
# Fairness (Skill Difference): 2.87
# Precision (Balance of the teams): 0.26
#
# × Attempt 34 ×
# Team 2:
#    Player  SkillRating
#  Player56     0.268606
#  Player66     0.868816
# Player143     0.859454
#  Player55     0.756308
# Player127     0.045526
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.80
# Fairness (Skill Difference): 2.20
# Precision (Balance of the teams): 0.31
#
# × Attempt 35 ×
# Team 2:
#    Player  SkillRating
#  Player81     0.193907
#  Player50     0.328119
# Player135     0.960674
# Player141     0.803060
#  Player69     0.014513
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.30
# Fairness (Skill Difference): 2.70
# Precision (Balance of the teams): 0.27
#
# × Attempt 36 ×
# Team 2:
#    Player  SkillRating
#  Player59     0.016268
# Player122     0.542332
#  Player60     0.004512
# Player144     0.974326
#  Player21     0.900739
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.44
# Fairness (Skill Difference): 2.56
# Precision (Balance of the teams): 0.28
#
# × Attempt 37 ×
# Team 2:
#    Player  SkillRating
#   Player7     0.997272
# Player149     0.969792
# Player128     0.996869
#  Player39     0.992329
#  Player43     0.154134
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 4.11
# Fairness (Skill Difference): 0.89
# Precision (Balance of the teams): 0.53
#
# × Attempt 38 ×
# Team 2:
#    Player  SkillRating
#  Player92     0.910846
#  Player28     0.083457
# Player103     0.988422
#  Player58     0.018782
#  Player82     0.974849
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.98
# Fairness (Skill Difference): 2.02
# Precision (Balance of the teams): 0.33
#
# × Attempt 39 ×
# Team 2:
#    Player  SkillRating
#  Player30     0.942929
#  Player71     0.046209
#  Player96     0.064459
# Player145     0.986853
#  Player98     0.014025
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.05
# Fairness (Skill Difference): 2.94
# Precision (Balance of the teams): 0.25
#
# × Attempt 40 ×
# Team 2:
#    Player  SkillRating
# Player120     0.994753
#  Player61     0.038503
# Player136     0.035489
# Player147     0.009133
# Player149     0.969792
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.05
# Fairness (Skill Difference): 2.95
# Precision (Balance of the teams): 0.25
#
# × Attempt 41 ×
# Team 2:
#    Player  SkillRating
#  Player67     0.051440
# Player112     0.430170
# Player134     0.051987
# Player120     0.994753
# Player108     0.887631
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.42
# Fairness (Skill Difference): 2.58
# Precision (Balance of the teams): 0.28
#
# × Attempt 42 ×
# Team 2:
#    Player  SkillRating
# Player110     0.728264
#  Player61     0.038503
#  Player82     0.974849
#  Player89     0.179606
#  Player81     0.193907
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.12
# Fairness (Skill Difference): 2.88
# Precision (Balance of the teams): 0.26
#
# × Attempt 43 ×
# Team 2:
#    Player  SkillRating
# Player143     0.859454
#  Player36     0.269491
# Player144     0.974326
#  Player84     0.997575
# Player105     0.047868
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 3.15
# Fairness (Skill Difference): 1.85
# Precision (Balance of the teams): 0.35
#
# × Attempt 44 ×
# Team 2:
#    Player  SkillRating
#  Player92     0.910846
#  Player19     0.259313
# Player131     0.994240
#  Player14     0.011411
# Player115     0.425807
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.60
# Fairness (Skill Difference): 2.40
# Precision (Balance of the teams): 0.29
#
# × Attempt 45 ×
# Team 2:
#    Player  SkillRating
# Player121     0.670517
#  Player85     0.054628
#  Player13     0.989955
# Player100     0.747504
#  Player51     0.915073
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 3.38
# Fairness (Skill Difference): 1.62
# Precision (Balance of the teams): 0.38
#
# × Attempt 46 ×
# Team 2:
#    Player  SkillRating
# Player138     0.686361
#  Player83     0.478687
#   Player5     0.618520
# Player125     0.942974
#  Player36     0.269491
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 3.00
# Fairness (Skill Difference): 2.00
# Precision (Balance of the teams): 0.33
#
# × Attempt 47 ×
# Team 2:
#    Player  SkillRating
#  Player83     0.478687
#  Player10     0.997955
# Player120     0.994753
#  Player80     0.049415
#  Player38     0.781405
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 3.30
# Fairness (Skill Difference): 1.69
# Precision (Balance of the teams): 0.37
#
# × Attempt 48 ×
# Team 2:
#    Player  SkillRating
#  Player91     0.989575
#  Player42     0.146179
# Player118     0.467721
#  Player67     0.051440
# Player124     0.768164
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.42
# Fairness (Skill Difference): 2.57
# Precision (Balance of the teams): 0.28
#
# × Attempt 49 ×
# Team 2:
#    Player  SkillRating
#   Player1     0.997201
#  Player34     0.978692
#  Player66     0.868816
# Player113     0.070160
#  Player76     0.990286
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 3.91
# Fairness (Skill Difference): 1.09
# Precision (Balance of the teams): 0.48
#
# × Attempt 50 ×
# Team 2:
#    Player  SkillRating
# Player105     0.047868
# Player116     0.773957
#  Player38     0.781405
#  Player99     0.957700
#  Player56     0.268606
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.83
# Fairness (Skill Difference): 2.17
# Precision (Balance of the teams): 0.32
#
# × Attempt 51 ×
# Team 2:
#    Player  SkillRating
# Player126     0.109776
#  Player74     0.960931
#  Player79     0.986732
# Player104     0.192236
#  Player67     0.051440
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.30
# Fairness (Skill Difference): 2.70
# Precision (Balance of the teams): 0.27
#
# × Attempt 52 ×
# Team 2:
#    Player  SkillRating
#  Player45     0.481439
#  Player89     0.179606
#  Player19     0.259313
# Player119     0.990757
#  Player25     0.989322
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.90
# Fairness (Skill Difference): 2.10
# Precision (Balance of the teams): 0.32
#
# × Attempt 53 ×
# Team 2:
#   Player  SkillRating
# Player39     0.992329
#  Player8     0.003246
# Player24     0.000062
# Player91     0.989575
# Player51     0.915073
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.90
# Fairness (Skill Difference): 2.10
# Precision (Balance of the teams): 0.32
#
# × Attempt 54 ×
# Team 2:
#    Player  SkillRating
#  Player89     0.179606
# Player108     0.887631
#  Player28     0.083457
#  Player43     0.154134
# Player118     0.467721
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 1.77
# Fairness (Skill Difference): 3.22
# Precision (Balance of the teams): 0.24
#
# × Attempt 55 ×
# Team 2:
#    Player  SkillRating
#  Player37     0.789347
# Player100     0.747504
#  Player44     0.766610
#  Player78     0.956867
#  Player27     0.099857
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 3.36
# Fairness (Skill Difference): 1.64
# Precision (Balance of the teams): 0.38
#
# × Attempt 56 ×
# Team 2:
#   Player  SkillRating
# Player55     0.756308
# Player99     0.957700
# Player52     0.141043
# Player63     0.227637
# Player50     0.328119
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.41
# Fairness (Skill Difference): 2.59
# Precision (Balance of the teams): 0.28
#
# × Attempt 57 ×
# Team 2:
#    Player  SkillRating
#  Player75     0.518849
# Player123     0.931569
#  Player88     0.466279
#  Player68     0.860783
#  Player93     0.738337
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 3.52
# Fairness (Skill Difference): 1.48
# Precision (Balance of the teams): 0.40
#
# × Attempt 58 ×
# Team 2:
#   Player  SkillRating
# Player39     0.992329
# Player83     0.478687
#  Player1     0.997201
# Player71     0.046209
# Player96     0.064459
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.58
# Fairness (Skill Difference): 2.42
# Precision (Balance of the teams): 0.29
#
# × Attempt 59 ×
# Team 2:
#    Player  SkillRating
#  Player95     0.404965
# Player140     0.513909
# Player101     0.852247
#  Player70     0.035994
# Player150     0.995809
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.80
# Fairness (Skill Difference): 2.19
# Precision (Balance of the teams): 0.31
#
# × Attempt 60 ×
# Team 2:
#   Player  SkillRating
# Player44     0.766610
# Player50     0.328119
# Player76     0.990286
# Player16     0.241174
# Player26     0.055773
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 2.38
# Fairness (Skill Difference): 2.61
# Precision (Balance of the teams): 0.28
#
# × Attempt 61 ×
# Team 2:
#   Player  SkillRating
# Player42     0.146179
# Player86     0.136276
# Player44     0.766610
# Player20     0.423546
# Player95     0.404965
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 1.88
# Fairness (Skill Difference): 3.12
# Precision (Balance of the teams): 0.24
#
# × Attempt 62 ×
# Team 2:
#    Player  SkillRating
# Player119     0.990757
# Player144     0.974326
#   Player6     0.980940
#  Player74     0.960931
#  Player53     0.908849
#
# Team 1 Total Skill: 5.00
# Team 2 Total Skill: 4.82
# Fairness (Skill Difference): 0.18
# Precision (Balance of the teams): 0.85
#
# ✅ Highly Balanced Match Found!
#
# Final Matched Team 2:
#    Player  SkillRating
# Player119     0.990757
# Player144     0.974326
#   Player6     0.980940
#  Player74     0.960931
#  Player53     0.908849
#
# Fairness Score: 0.18
# Precision Score: 0.85 (Closer to 1 is better)
#
# Total Attempts Made: 62
#
# --- End of Simulation ---

# %% [markdown]
# ## SCENARIO 2: Solo Queue Player Fixed

# %%
import pandas as pd
import numpy as np
import joblib
import random
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="sklearn")

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Load the saved model
model_path = '/content/drive/MyDrive/Final Year Project - APIIT/Models/logistic_regression_model.pkl'
model = joblib.load(model_path)

# Load the testing dataset
test_data_path = '/content/drive/MyDrive/Final Year Project - APIIT/Datasets/testing_data.csv'
test_data = pd.read_csv(test_data_path)

# Add player identifiers
test_data['Player'] = ['Player' + str(i) for i in range(1, len(test_data) + 1)]

# Separate features
X_test = test_data.drop(columns=['Target', 'Player'])
y_test = test_data['Target']

# Predict skill rating
test_data['SkillRating'] = model.predict_proba(X_test)[:, 1]
df_sorted = test_data.sort_values(by='SkillRating', ascending=False).reset_index(drop=True)

# Scenario 2 Header
print("\033[1m" + "="*55)
print(" SCENARIO 2: Solo Queue (One Player Fixed in Team 1)")
print("="*55 + "\033[0m\n")

# Fix one solo player into Team 1 (e.g., Player1)
solo_player = df_sorted.iloc[0][['Player', 'SkillRating']].tolist()
solo_label = f"→ {solo_player[0]} (Fixed Solo Player)"
print("\033[1;36mFixed Solo Player in Team 1:\033[0m")
print(pd.DataFrame([[solo_label, solo_player[1]]], columns=['Player', 'SkillRating']).to_string(index=False))

# Remaining players
remaining_pool = df_sorted.iloc[1:][['Player', 'SkillRating']].values.tolist()
found_match = False
attempts = 0

while not found_match and len(remaining_pool) >= 9:  # need 9 others to make 5v5
    random.shuffle(remaining_pool)
    team1_raw = [solo_player] + remaining_pool[:4]
    team2 = remaining_pool[4:9]

    # Highlight solo player in team1
    team1_display = [[f"→ {p[0]}", p[1]] if p[0] == solo_player[0] else [p[0], p[1]] for p in team1_raw]

    total1 = sum(p[1] for p in team1_raw)
    total2 = sum(p[1] for p in team2)
    fairness = abs(total1 - total2)
    precision = 1 / (1 + fairness)

    attempts += 1

    print(f"\n\033[1m× Attempt {attempts} ×\033[0m")
    print("\033[94mTeam 1:\033[0m")
    print(pd.DataFrame(team1_display, columns=['Player', 'SkillRating']).to_string(index=False))
    print("\n\033[94mTeam 2:\033[0m")
    print(pd.DataFrame(team2, columns=['Player', 'SkillRating']).to_string(index=False))

    print(f"\n\033[93mTeam 1 Total Skill:\033[0m {total1:.2f}")
    print(f"\033[93mTeam 2 Total Skill:\033[0m {total2:.2f}")
    print(f"\033[95mFairness (Skill Difference):\033[0m {fairness:.2f}")
    print(f"\033[92mPrecision (Balance of the teams):\033[0m {precision:.2f}")

    if precision > 0.8:
        found_match = True
        print("\n\033[1;32m✅ Highly Balanced Match Found!\033[0m")
        print("\n\033[1;34mFinal Team 1 (Including Solo Player):\033[0m")
        print(pd.DataFrame(team1_display, columns=['Player', 'SkillRating']).to_string(index=False))
        print("\n\033[1;34mFinal Team 2 (Opponent Team):\033[0m")
        print(pd.DataFrame(team2, columns=['Player', 'SkillRating']).to_string(index=False))
        print(f"\n\033[92mFinal Precision Score:\033[0m {precision:.2f} \033[90m(Closer to 1 means more balance)\033[0m")
        break

if not found_match:
    print("\n\033[1;31m❌ Could not find a highly balanced team after several attempts.\033[0m")

print(f"\n\033[1mTotal Attempts Made:\033[0m {attempts}")
print("\n\033[90m--- End of Simulation ---\033[0m")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# =======================================================
#  SCENARIO 2: Solo Queue (One Player Fixed in Team 1)
# =======================================================
#
# Fixed Solo Player in Team 1:
#                          Player  SkillRating
# → Player142 (Fixed Solo Player)     0.999903
#
# × Attempt 1 ×
# Team 1:
#      Player  SkillRating
# → Player142     0.999903
#    Player91     0.989575
#    Player31     0.951292
#   Player132     0.065781
#   Player143     0.859454
#
# Team 2:
#    Player  SkillRating
# Player147     0.009133
#  Player40     0.117620
# Player122     0.542332
#  Player44     0.766610
#  Player34     0.978692
#
# Team 1 Total Skill: 3.87
# Team 2 Total Skill: 2.41
# Fairness (Skill Difference): 1.45
# Precision (Balance of the teams): 0.41
#
# × Attempt 2 ×
# Team 1:
#      Player  SkillRating
# → Player142     0.999903
#    Player12     0.079175
#   Player131     0.994240
#    Player28     0.083457
#   Player126     0.109776
#
# Team 2:
#    Player  SkillRating
#  Player23     0.153125
# Player130     0.928663
#  Player79     0.986732
#  Player15     0.001684
#  Player84     0.997575
#
# Team 1 Total Skill: 2.27
# Team 2 Total Skill: 3.07
# Fairness (Skill Difference): 0.80
# Precision (Balance of the teams): 0.56
#
# × Attempt 3 ×
# Team 1:
#      Player  SkillRating
# → Player142     0.999903
#    Player81     0.193907
#   Player134     0.051987
#    Player32     0.626015
#   Player132     0.065781
#
# Team 2:
#    Player  SkillRating
#  Player79     0.986732
# Player137     0.086768
# Player112     0.430170
#  Player98     0.014025
#  Player16     0.241174
#
# Team 1 Total Skill: 1.94
# Team 2 Total Skill: 1.76
# Fairness (Skill Difference): 0.18
# Precision (Balance of the teams): 0.85
#
# ✅ Highly Balanced Match Found!
#
# Final Team 1 (Including Solo Player):
#      Player  SkillRating
# → Player142     0.999903
#    Player81     0.193907
#   Player134     0.051987
#    Player32     0.626015
#   Player132     0.065781
#
# Final Team 2 (Opponent Team):
#    Player  SkillRating
#  Player79     0.986732
# Player137     0.086768
# Player112     0.430170
#  Player98     0.014025
#  Player16     0.241174
#
# Final Precision Score: 0.85 (Closer to 1 means more balance)
#
# Total Attempts Made: 3
#
# --- End of Simulation ---
